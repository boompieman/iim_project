# %%
#coding=utf-8
# Topic Parser
# Description:
#    而每一份中會有數個會議檔案，用小寫編號 eg. ES2002a, ES2002b...
#    每個檔案中會有數個人講話，用大寫編號 eg. A, B, C...
# Usage:
#    輸入欲分析的檔案，一直按指令即可

# %%
import xml.etree.ElementTree as ET

# %%
filePrefix = 'ES2002a'

# %%
fileRoot = filePrefix + '.topic'

# %%
fileName= '../AMI_corpus_resources/topics/' + fileRoot + '.xml'

# %%
tree = ET.parse(fileName)

# %%
root = tree.getroot()

# %%
idName = '{http://nite.sourceforge.net/}id'

# %%
import re # regrssion expression

# %%
# find complete matched content
def findTotalWord(totalContent):
    pattern = 'id\((\w+\.\w\.\w+)\)'
    matched = re.findall(pattern, totalContent)
    return matched

# %%
# print word indexes
def getWordIndex(matched):
    wordList = []
    if len(matched) == 1:
        wordList.append(matched[0])
    else:
        # parse the word index
        start = matched[0]
        end = matched[1]
        pattern = '\d+'
        startIndexes = re.findall(pattern, start)
        endIndexes = re.findall(pattern, end)
        startWordIndex = startIndexes[1]
        endWordIndex = endIndexes[1]

        # find the prefix # eg. ES2002a.B.words
        prefixPattern = '\D+\d+\D\.\D+\.\D+'
        prefix = re.match(prefixPattern, start)
        prefixStr = prefix.group(0)
        
        # conbine the prefix and the word index
        for index in range(int(startWordIndex), int(endWordIndex) + 1):
             wordList.append(prefixStr + str(index))
    return wordList

# %%
# content
totalContents = []
for topic in root.iter('topic'):
    aTopicDic = {}
    
    topicDescription = topic.get('other_description')
    topicID = topic.get(idName)  # get: find attribute's content
    
    # check the description and ID exists
    if topicDescription:
        aTopicDic['topicDescription'] = topicDescription
    if topicID:
        aTopicDic['topicID'] = topicID
    
    # join matched indexes of words
    matchWordsIndexes = []
    for child in topic.iter('{http://nite.sourceforge.net/}child'):
        href = child.get('href')
        totalWordStr = findTotalWord(href)
        
        tempWordIndexes = getWordIndex(totalWordStr)
        for wordIndex in range(len(tempWordIndexes)):
            matchWordsIndexes.append(tempWordIndexes[wordIndex])
        
    # store the match words indexes to aTopicDic
    aTopicDic['wordsIndexes'] = matchWordsIndexes
    
    # store retrieved dict to array
    totalContents.append(aTopicDic)

# %%
print totalContents
# Out:
# [{'topicDescription': 'introduction of participants and their roles', 'wordsIndexes': ['ES2002a.B.words0', 'ES2002a.B.words1', 'ES2002a.B.words2', 'ES2002a.B.words3', 'ES2002a.B.words4', 'ES2002a.B.words5', 'ES2002a.B.words6', 'ES2002a.B.words7', 'ES2002a.B.words8', 'ES2002a.B.words9', 'ES2002a.B.words10', 'ES2002a.B.words11', 'ES2002a.B.words12', 'ES2002a.B.words13', 'ES2002a.B.words14', 'ES2002a.B.words15', 'ES2002a.B.words16', 'ES2002a.B.words17', 'ES2002a.B.words18', 'ES2002a.B.words19', 'ES2002a.B.words20', 'ES2002a.B.words21', 'ES2002a.B.words22', 'ES2002a.B.words23', 'ES2002a.B.words24', 'ES2002a.B.words25', 'ES2002a.B.words26', 'ES2002a.B.words27', 'ES2002a.B.words28', 'ES2002a.B.words29', 'ES2002a.B.words30', 'ES2002a.B.words31', 'ES2002a.B.words32', 'ES2002a.B.words33', 'ES2002a.B.words34', 'ES2002a.B.words35', 'ES2002a.B.words36', 'ES2002a.B.words37', 'ES2002a.B.words38', 'ES2002a.B.words39', 'ES2002a.B.words40', 'ES2002a.B.words41', 'ES2002a.B.words42', 'ES2002a.B.words43', 'ES2002a.B.words44', 'ES2002a.B.words45', 'ES2002a.B.words46', 'ES2002a.B.words47', 'ES2002a.B.words48', 'ES2002a.B.words49', 'ES2002a.B.words50', 'ES2002a.B.words51', 'ES2002a.B.words52', 'ES2002a.B.words53', 'ES2002a.B.words54', 'ES2002a.B.words55', 'ES2002a.B.words56', 'ES2002a.B.words57', 'ES2002a.B.words58', 'ES2002a.B.words59', 'ES2002a.B.words60', 'ES2002a.B.words61', 'ES2002a.B.words62', 'ES2002a.B.words63', 'ES2002a.B.words64', 'ES2002a.B.words65', 'ES2002a.B.words66', 'ES2002a.B.words67', 'ES2002a.B.words68', 'ES2002a.B.words69', 'ES2002a.B.words70', 'ES2002a.B.words71', 'ES2002a.D.words0', 'ES2002a.D.words1', 'ES2002a.D.words2', 'ES2002a.D.words3', 'ES2002a.A.words0', 'ES2002a.A.words1', 'ES2002a.A.words2', 'ES2002a.A.words3', 'ES2002a.A.words4', 'ES2002a.A.words5', 'ES2002a.A.words6', 'ES2002a.A.words7', 'ES2002a.A.words8', 'ES2002a.A.words9', 'ES2002a.A.words10', 'ES2002a.A.words11', 'ES2002a.A.words12', 'ES2002a.B.words72', 'ES2002a.B.words73', 'ES2002a.D.words4', 'ES2002a.D.words5', 'ES2002a.D.words6', 'ES2002a.D.words7', 'ES2002a.D.words8', 'ES2002a.D.words9', 'ES2002a.D.words10', 'ES2002a.D.words11', 'ES2002a.C.words0', 'ES2002a.C.words1', 'ES2002a.C.words2', 'ES2002a.C.words3', 'ES2002a.C.words4', 'ES2002a.C.words5', 'ES2002a.C.words6', 'ES2002a.C.words7', 'ES2002a.D.words12', 'ES2002a.D.words13'], 'topicID': 'ES2002a.topic.vkaraisk.1'}, {'topicDescription': 'project goals and design process', 'wordsIndexes': ['ES2002a.B.words74', 'ES2002a.B.words75', 'ES2002a.B.words76', 'ES2002a.B.words77', 'ES2002a.B.words78', 'ES2002a.B.words79', 'ES2002a.B.words80', 'ES2002a.B.words81', 'ES2002a.B.words82', 'ES2002a.B.words83', 'ES2002a.B.words84', 'ES2002a.B.words85', 'ES2002a.B.words86', 'ES2002a.B.words87', 'ES2002a.B.words88', 'ES2002a.B.words89', 'ES2002a.B.words90', 'ES2002a.B.words91', 'ES2002a.B.words92', 'ES2002a.B.words93', 'ES2002a.B.words94', 'ES2002a.B.words95', 'ES2002a.B.words96', 'ES2002a.B.words97', 'ES2002a.B.words98', 'ES2002a.B.words99', 'ES2002a.B.words100', 'ES2002a.B.words101', 'ES2002a.B.words102', 'ES2002a.B.words103', 'ES2002a.B.words104', 'ES2002a.B.words105', 'ES2002a.B.words106', 'ES2002a.B.words107', 'ES2002a.B.words108', 'ES2002a.B.words109', 'ES2002a.B.words110', 'ES2002a.B.words111', 'ES2002a.B.words112', 'ES2002a.B.words113', 'ES2002a.B.words114', 'ES2002a.B.words115', 'ES2002a.B.words116', 'ES2002a.B.words117', 'ES2002a.B.words118', 'ES2002a.B.words119', 'ES2002a.B.words120', 'ES2002a.B.words121', 'ES2002a.B.words122', 'ES2002a.B.words123', 'ES2002a.B.words124', 'ES2002a.B.words125', 'ES2002a.B.words126', 'ES2002a.B.words127', 'ES2002a.B.words128', 'ES2002a.B.words129', 'ES2002a.B.words130', 'ES2002a.B.words131', 'ES2002a.B.words132', 'ES2002a.B.words133', 'ES2002a.B.words134', 'ES2002a.B.words135', 'ES2002a.B.words136', 'ES2002a.B.words137', 'ES2002a.B.words138', 'ES2002a.B.words139', 'ES2002a.B.words140', 'ES2002a.B.words141', 'ES2002a.B.words142', 'ES2002a.B.words143', 'ES2002a.B.words144', 'ES2002a.B. ...

# %%
# connect to database
import pymysql
connection = pymysql.connect(host='140.116.112.164',
                             user='iim_project',
                             password='1qaz2wsx3eDC',
                             db='topic_to_what_words',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)

cursor = connection.cursor()

# %%
# create table
sql_create = "create table `%s` (id int(11) NOT NULL AUTO_INCREMENT, topic varchar(255), relatedWordPos varchar(255), topicID varchar(255), PRIMARY KEY(id)) ENGINE=InnoDB DEFAULT CHARSET=utf8 COLLATE=utf8_bin AUTO_INCREMENT=1" 
print sql_create
# Out:
# create table `%s` (id int(11) NOT NULL AUTO_INCREMENT, topic varchar(255), relatedWordPos varchar(255), topicID varchar(255), PRIMARY KEY(id)) ENGINE=InnoDB DEFAULT CHARSET=utf8 COLLATE=utf8_bin AUTO_INCREMENT=1

# %%
fileTableName = fileRoot + '_to_words'
print fileTableName
# Out:
# ES2002a.topic_to_words

# %%
cursor.execute(sql_create, fileTableName)
connection.commit()

# %%
sql_insert = "insert into `%s` (topic, relatedWordPos, topicID) values(%s, %s, %s)"

for aTopicDic in totalContents:
    topicDescription = ""
    if aTopicDic['topicDescription']:
        topicDescription = aTopicDic['topicDescription']
    topicID = aTopicDic['topicID']
    wordsInTopic = aTopicDic['wordsIndexes']
    for wordPos in wordsInTopic:
        cursor.execute(sql_insert,(fileTableName, topic, wordPos, topicID))
        
connection.commit()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-1377c005f7ec> in <module>()
#       2
#       3 for aTopicDic in totalContents:
# ----> 4     topic = aTopicDic['topicDescription']
#       5     topicID = aTopicDic['topicID']
#       6     wordsInTopic = aTopicDic['wordsIndexes']
#
# KeyError: 'topicDescription'
